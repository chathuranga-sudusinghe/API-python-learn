# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %%
# !pip install randomuser
from randomuser import RandomUser
import pandas as pd
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=74f57b7e4363728b460b4e9f20c4cbfc4b6d380d018698054673286ababd598e
#   Stored in directory: /root/.cache/pip/wheels/be/62/c8/71e1b48f4758ea5b78af7595d87178f628cde315a3326610ee
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
r = RandomUser()
r

# %% [markdown]
# ## using generate_users() function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)
some_list
# Out:
# [<randomuser.RandomUser at 0x7ee8582dc9b0>,
#  <randomuser.RandomUser at 0x7ee8582ddfd0>,
#  <randomuser.RandomUser at 0x7ee8582dee10>,
#  <randomuser.RandomUser at 0x7ee8582dec00>,
#  <randomuser.RandomUser at 0x7ee8582de330>,
#  <randomuser.RandomUser at 0x7ee8582dc0b0>,
#  <randomuser.RandomUser at 0x7ee8582dee40>,
#  <randomuser.RandomUser at 0x7ee8582dda60>,
#  <randomuser.RandomUser at 0x7ee8582de8d0>,
#  <randomuser.RandomUser at 0x7ee8582de510>]

# %%
name = r.get_full_name()
name
# Out:
# 'Ava Novak'

# %% [markdown]
# ## 10 users with full names and their email addresses.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Azuil da Cruz   azuil.dacruz@example.com
# Owen Gonzalez   owen.gonzalez@example.com
# Emilie Johansen   emilie.johansen@example.com
# Alejandro Alvarez   alejandro.alvarez@example.com
# Gotthold Nau   gotthold.nau@example.com
# Ross Barrett   ross.barrett@example.com
# Elias Mortensen   elias.mortensen@example.com
# Storm Jørgensen   storm.jorgensen@example.com
# Anésia Cardoso   anesia.cardoso@example.com
# Saula Carvalho   saula.carvalho@example.com

# %% [markdown]
# ## Generate photos full names of the random 10 users.

# %%
for user in some_list:
    print(user.get_full_name(), " " , user.get_picture())
# Out:
# Azuil da Cruz   https://randomuser.me/api/portraits/men/88.jpg
# Owen Gonzalez   https://randomuser.me/api/portraits/men/11.jpg
# Emilie Johansen   https://randomuser.me/api/portraits/women/8.jpg
# Alejandro Alvarez   https://randomuser.me/api/portraits/men/73.jpg
# Gotthold Nau   https://randomuser.me/api/portraits/men/37.jpg
# Ross Barrett   https://randomuser.me/api/portraits/men/55.jpg
# Elias Mortensen   https://randomuser.me/api/portraits/men/13.jpg
# Storm Jørgensen   https://randomuser.me/api/portraits/men/51.jpg
# Anésia Cardoso   https://randomuser.me/api/portraits/women/84.jpg
# Saula Carvalho   https://randomuser.me/api/portraits/women/78.jpg

# %% [markdown]
# ## To generate a table with information about the users
#
# ### RandomUser API generates new random users every time you call it

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({
            "Name":user.get_full_name(),
            "Gender":user.get_gender(),
            "City":user.get_city(),
            "State":user.get_state(),
            "Email":user.get_email(), 
            "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)   

users = get_users()
print(users)
# Out:
#               Name  Gender        City                State  \
# 0  Laura Rasmussen  female    Tisvilde          Nordjylland
# 1     Koray Denkel    male    Erzincan            Zonguldak
# 2    Héloïse Duval  female       Dijon                Doubs
# 3      Zenon Rohde    male       Leuna  Nordrhein-Westfalen
# 4    Marcelle Joly  female  Montanaire                 Vaud
# 5     Niene Garcia  female    Rinnegom              Zeeland
# 6        Ali Polat    male   Eskişehir                Konya
# 7  Kaya Berberoğlu    male      Manisa               Samsun
# 8      Edward Bell    male      Lowell              Indiana
# 9       Lesley Ngo  female   Bleiswijk        Noord-Brabant
#
#                          Email                       DOB  \
# 0  laura.rasmussen@example.com  1976-07-20T02:57:05.139Z
# 1     koray.denkel@example.com  1993-12-08T02:04:10.271Z
# 2    heloise.duval@example.com  1963-05-14T12:26:46.154Z
# 3      zenon.rohde@example.com  1982-02-02T23:23:53.731Z
# 4    marcelle.joly@example.com  1984-03-30T14:20:31.330Z
# 5     niene.garcia@example.com  1974-03-30T00:14:03.547Z
# 6        ali.polat@example.com  1978-08-30T18:15:50.901Z
# 7  kaya.berberoglu@example.com  1948-04-24T00:29:40.296Z
# 8      edward.bell@example.com  1955-06-26T16:21:39.704Z
# 9       lesley.ngo@example.com  1978-02-03T21:56:25.778Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/70.jpg
# 1    https://randomuser.me/api/portraits/men/83.jpg
# 2  https://randomuser.me/api/portraits/women/50.jpg
# 3    https://randomuser.me/api/portraits/men/25.jpg
# 4  https://randomuser.me/api/portraits/women/58.jpg
# 5  https://randomuser.me/api/portraits/women/81.jpg
# 6     https://randomuser.me/api/portraits/men/8.jpg
# 7    https://randomuser.me/api/portraits/men/90.jpg
# 8    https://randomuser.me/api/portraits/men/72.jpg
# 9  https://randomuser.me/api/portraits/women/12.jpg

# %% [markdown]
# ## 4 types get table visual

# %%
get_users()
# Out:
#               Name  Gender             City          State  \
# 0      Esma Mayhoş  female           Samsun      Çanakkale
# 1  Suzanne Ramirez  female         Berkeley        Vermont
# 2    Nella Huhtala  female         Karijoki        Lapland
# 3    Oscar Lemaire    male            Lille    Haute-Marne
# 4    Calvin Fowler    male        Newbridge          Louth
# 5   Arnaud Ouellet    male         Red Rock       Manitoba
# 6     Matias Lahti    male       Polvijärvi  North Karelia
# 7   Jonas Andersen    male           Roslev        Danmark
# 8    Paula Lemaire  female  Plan-les-Ouates            Zug
# 9       Bela Erler    male     Geringswalde  Niedersachsen
#
#                          Email                       DOB  \
# 0      esma.mayhos@example.com  1982-06-17T11:26:17.698Z
# 1  suzanne.ramirez@example.com  1966-05-24T02:45:58.763Z
# 2    nella.huhtala@example.com  1978-02-08T12:02:48.509Z
# 3    oscar.lemaire@example.com  1988-03-03T22:17:25.672Z
# 4    calvin.fowler@example.com  1949-02-11T12:37:16.820Z
# 5   arnaud.ouellet@example.com  1963-09-18T23:38:37.052Z
# 6     matias.lahti@example.com  1987-05-02T20:37:28.710Z
# 7   jonas.andersen@example.com  1992-08-13T08:13:45.325Z
# 8    paula.lemaire@example.com  1962-03-03T11:59:54.711Z
# 9       bela.erler@example.com  1975-02-09T00:55:47.287Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/75.jpg
# 1  https://randomuser.me/api/portraits/women/31.jpg
# 2   https://randomuser.me/api/portraits/women/3.jpg
# 3    https://randomuser.me/api/portraits/men/39.jpg
# 4    https://randomuser.me/api/portraits/men/25.jpg
# 5     https://randomuser.me/api/portraits/men/0.jpg
# 6    https://randomuser.me/api/portraits/men/69.jpg
# 7    https://randomuser.me/api/portraits/men/79.jpg
# 8  https://randomuser.me/api/portraits/women/67.jpg
# 9    https://randomuser.me/api/portraits/men/28.jpg

# %%
df1 = pd.DataFrame(get_users())  
df1
# Out:
#                 Name  Gender                        City  \
# 0         Emil Lehto    male                      Alavus
# 1      Jessica Garza  female                      Armagh
# 2  Rudinele Carvalho  female               Volta Redonda
# 3      فاطمه علیزاده  female                         خوی
# 4         Kerttu Aho  female                    Kalajoki
# 5     Eduardo Torres    male  San Sebastián de Los Reyes
# 6         Mia Wilson  female                  Georgetown
# 7   Filippa Johansen  female                    Tisvilde
# 8      Victoria Wong  female                     Trenton
# 9        Borja Rubio    male                    Alicante
#
#                    State                          Email  \
# 0  Southern Ostrobothnia         emil.lehto@example.com
# 1        Nottinghamshire      jessica.garza@example.com
# 2               Maranhão  rudinele.carvalho@example.com
# 3                  همدان       ftmh.aalyzdh@example.com
# 4  Southern Ostrobothnia         kerttu.aho@example.com
# 5            Extremadura     eduardo.torres@example.com
# 6           Saskatchewan         mia.wilson@example.com
# 7            Midtjylland   filippa.johansen@example.com
# 8           Saskatchewan      victoria.wong@example.com
# 9               Cataluña        borja.rubio@example.com
#
#                         DOB                                           Picture
# 0  1946-02-06T20:36:15.181Z    https://randomuser.me/api/portraits/men/72.jpg
# 1  1945-09-01T05:08:36.689Z  https://randomuser.me/api/portraits/women/68.jpg
# 2  1975-07-21T19:07:12.647Z  https://randomuser.me/api/portraits/women/40.jpg
# 3  1980-02-01T14:11:46.309Z  https://randomuser.me/api/portraits/women/45.jpg
# 4  1990-02-28T16:08:02.713Z  https://randomuser.me/api/portraits/women/88.jpg
# 5  1985-06-08T20:18:33.643Z    https://randomuser.me/api/portraits/men/40.jpg
# 6  1964-01-30T13:00:19.186Z  https://randomuser.me/api/portraits/women/63.jpg
# 7  1969-10-07T16:00:01.847Z  https://randomuser.me/api/portraits/women/83.jpg
# 8  1964-03-23T02:27:53.404Z  https://randomuser.me/api/portraits/women/45.jpg
# 9  1977-01-13T19:47:01.647Z    https://randomuser.me/api/portraits/men/91.jpg

# %%
display(df1)
# Out:
#                 Name  Gender                        City  \
# 0         Emil Lehto    male                      Alavus
# 1      Jessica Garza  female                      Armagh
# 2  Rudinele Carvalho  female               Volta Redonda
# 3      فاطمه علیزاده  female                         خوی
# 4         Kerttu Aho  female                    Kalajoki
# 5     Eduardo Torres    male  San Sebastián de Los Reyes
# 6         Mia Wilson  female                  Georgetown
# 7   Filippa Johansen  female                    Tisvilde
# 8      Victoria Wong  female                     Trenton
# 9        Borja Rubio    male                    Alicante
#
#                    State                          Email  \
# 0  Southern Ostrobothnia         emil.lehto@example.com
# 1        Nottinghamshire      jessica.garza@example.com
# 2               Maranhão  rudinele.carvalho@example.com
# 3                  همدان       ftmh.aalyzdh@example.com
# 4  Southern Ostrobothnia         kerttu.aho@example.com
# 5            Extremadura     eduardo.torres@example.com
# 6           Saskatchewan         mia.wilson@example.com
# 7            Midtjylland   filippa.johansen@example.com
# 8           Saskatchewan      victoria.wong@example.com
# 9               Cataluña        borja.rubio@example.com
#
#                         DOB                                           Picture
# 0  1946-02-06T20:36:15.181Z    https://randomuser.me/api/portraits/men/72.jpg
# 1  1945-09-01T05:08:36.689Z  https://randomuser.me/api/portraits/women/68.jpg
# 2  1975-07-21T19:07:12.647Z  https://randomuser.me/api/portraits/women/40.jpg
# 3  1980-02-01T14:11:46.309Z  https://randomuser.me/api/portraits/women/45.jpg
# 4  1990-02-28T16:08:02.713Z  https://randomuser.me/api/portraits/women/88.jpg
# 5  1985-06-08T20:18:33.643Z    https://randomuser.me/api/portraits/men/40.jpg
# 6  1964-01-30T13:00:19.186Z  https://randomuser.me/api/portraits/women/63.jpg
# 7  1969-10-07T16:00:01.847Z  https://randomuser.me/api/portraits/women/83.jpg
# 8  1964-03-23T02:27:53.404Z  https://randomuser.me/api/portraits/women/45.jpg
# 9  1977-01-13T19:47:01.647Z    https://randomuser.me/api/portraits/men/91.jpg
